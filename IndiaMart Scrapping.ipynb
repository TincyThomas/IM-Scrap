# %%
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
import pandas as pd
import time
import os
# Out:
# [WDM] - Driver [C:\Users\Tincy\.wdm\drivers\geckodriver\win64\v0.28.0\geckodriver.exe] found in cache

# %%
# driver.get method() will navigate to a page given by the URL address
driver.get("https://dir.indiamart.com/thrissur/civil-contractors.html")

# %%
storeDetails = driver.find_elements_by_class_name('clg')
names = driver.find_elements_by_class_name('lcname')
contactList = driver.find_elements_by_class_name('pns_h')

nameList = []
addressList = []
numbersList = []

for i in range(len(names)):
    
    name = names[i].text
    address = storeDetails[i].text
    contact = contactList[i].get_attribute("innerHTML")
    
    nameList.append(name)
    addressList.append(address)
    numbersList.append(contact)


    
# intialise data of lists.
data = {'Company Name':nameList,
        'Address': addressList,
        'Phone':numbersList}

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                                          Company Name  \
# 0                                    Skymark Builders
# 1                                     Tricon Builders
# 2      Fins Engineers And Contractors Private Limited
# 3                                            Mooncare
# 4                                   JP Arc Associates
# 5                                       Green Designz
# 6              Precious Infraprojects Private Limited
# 7                                   National Builders
# 8           Dreams World Living Space Private Limited
# 9                                      An Arch Design
# 10                      Calicut Construction Combines
# 11                  Phoenix Infrastructures & Project
# 12                                         La Venture
# 13  Precious Homes And Projects India Private Limited
# 14              Paithrukam Developers Private Limited
# 15                                  Govind Associates
# 16                    Park City Builders & Developers
# 17                  Nakshatra Builders and Developers
# 18                        Krishna Kripa Constructions
# 19                                   Vishnu Hardwares
# 20                                   E Home Interiors
#
#                                   Address        Phone
# 0                                Thrissur  08048835962
# 1   Pettumma, Kodungallur, Dist. Thrissur  08048882917
# 2                      Westfort, Thrissur  09846030947
# 3                    Ayyanthole, Thrissur  09388555657
# 4                                Thrissur  09747020230
# 5                                Thrissur  08136888304
# 6                 Church Circle, Thrissur  08048581321
# 7                    Marar Road, Thrissur  09446863183
# 8                     Guruvayur, Thrissur  08113866000
# 9                                Thrissur  09633576631
# 10                               Thrissur  09744184434
# 11                 Muruga Nagar, Thrissur  09895468584
# 12                               Thrissur  09526542008
# 13                               Thrissur  09400424444
# 14    Pullut, Kodungallur, Dist. Thrissur  09446995406
# 15           Kundoor Madom Road, Thrissur  09847036599
# 16                 Rays Complex, Thrissur  09961484343
# 17                  North Nada , Thrissur  08606492222
# 18                Kunnathumkara, Thrissur  09747496355
# 19                      Chazhur, Thrissur  09847138241
# 20                  Cheruvallur, Thrissur  09747037850

# %%
df.to_csv('demo2.csv', mode='a', header=False)
